# %% [markdown]
# # 🔹 1. Basic Greedy Foundations (Intro Level)
# | Level     | Problem                           | Platform      | Key Idea                               | Status |
# | --------- | --------------------------------- | ------------- | -------------------------------------- | ------ |
# | 🟢 Easy   | **Activity Selection Problem 🎯** | GFG           | Pick earliest finishing activity       |  ✔️     |
# | 🟢 Easy   | **Non-overlapping Intervals**     | Leetcode 435  | Remove minimum overlapping intervals   |  ✔️      |
# | 🟢 Easy   | **Assign Cookies**                | Leetcode 455  | Match smallest fitting cookie to child |     ✔️    |
# | 🟢 Easy   | **Lemonade Change**               | Leetcode 860  | Cash handling simulation               |  ✔️      |
# | 🟢 Easy   | **Maximum Units on Truck**        | Leetcode 1710 | Sort by units/box, greedy fill         |   ✔️     |
# | 🟡 Medium | **Gas Station**                   | Leetcode 134  | Local feasibility = global solution    |  ✔️      |

# %% [markdown]
# # 🔹 2. Greedy on Sorting / Scheduling
# | Level     | Problem                                | Platform     | Key Idea                                 | Status |
# | --------- | -------------------------------------- | ------------ | ---------------------------------------- | ------ |
# | 🟢 Easy   | **Activity Selection Problem (Again)** | GFG          | Sort by end time                         |        |
# | 🟡 Medium | **Job Sequencing Problem 🎯**          | GFG          | Maximize profit before deadline          |        |
# | 🟡 Medium | **Meeting Rooms I**                    | Leetcode 252 | Check conflicts via sorting              |        |
# | 🟡 Medium | **Meeting Rooms II**                   | Leetcode 253 | Count parallel intervals (heap assist)   |        |
# | 🟡 Medium | **Maximum Meetings in One Room**       | GFG          | Sort by end, choose non-overlapping      |        |
# | 🟡 Medium | **Reorganize String**                  | Leetcode 767 | Arrange characters greedily (heap logic) |        |

# %% [markdown]
# # 🔹 3. Greedy by Ratio (Knapsack / Selection)
# | Level     | Problem                             | Platform     | Key Idea                     | Status |
# | --------- | ----------------------------------- | ------------ | ---------------------------- | ------ |
# | 🟢 Easy   | **Fractional Knapsack 🎯**          | GFG          | Sort by value/weight ratio   |        |
# | 🟡 Medium | **Minimum Cost to Connect Ropes**   | GFG          | Merge two smallest each time |        |
# | 🟡 Medium | **Huffman Encoding**                | GFG          | Build min-heap by frequency  |        |
# | 🟡 Medium | **Greedy Florist**                  | HackerRank   | Sort descending by cost      |        |
# | 🟡 Medium | **Minimize the Maximum Difference** | GFG          | Balance extremes             |        |
# | 🟡 Medium | **Boats to Save People**            | Leetcode 881 | Two-pointer greedy pairing   |        |

# %% [markdown]
# # 🔹 4. Greedy in Arrays / Simulation Type
# | Level     | Problem                          | Platform     | Key Idea                          | Status |
# | --------- | -------------------------------- | ------------ | --------------------------------- | ------ |
# | 🟢 Easy   | **Largest Number After K Swaps** | GFG          | Local max digit swap              |        |
# | 🟢 Easy   | **Non-decreasing Array**         | Leetcode 665 | Fix violation with minimal change |        |
# | 🟢 Easy   | **Can Place Flowers**            | Leetcode 605 | Local placement feasibility       |        |
# | 🟡 Medium | **Jump Game 🎯**                 | Leetcode 55  | Max reachable index               |        |
# | 🟡 Medium | **Jump Game II**                 | Leetcode 45  | Greedy window jumps               |        |
# | 🟡 Medium | **Candy Distribution**           | Leetcode 135 | Forward + backward greedy pass    |        |

# %% [markdown]
# # 🔹 5. Greedy on Graph / Path Type
# | Level     | Problem                             | Platform      | Key Idea                            | Status |
# | --------- | ----------------------------------- | ------------- | ----------------------------------- | ------ |
# | 🟡 Medium | **Dijkstra’s Algorithm 🎯**         | GFG           | Shortest path using greedy distance |        |
# | 🟡 Medium | **Prim’s MST**                      | GFG           | Grow MST with min edge              |        |
# | 🟡 Medium | **Kruskal’s MST**                   | GFG           | Greedy edge picking using DSU       |        |
# | 🟡 Medium | **Network Delay Time**              | Leetcode 743  | Dijkstra variant                    |        |
# | 🟡 Medium | **Path With Minimum Effort**        | Leetcode 1631 | Binary + greedy combination         |        |
# | 🟡 Medium | **Cheapest Flights Within K Stops** | Leetcode 787  | Limited greedy + BFS hybrid         |        |

# %% [markdown]
# # 🔹 6. Greedy for String / Character Optimization
# | Level     | Problem                               | Platform     | Key Idea                     | Status |
# | --------- | ------------------------------------- | ------------ | ---------------------------- | ------ |
# | 🟢 Easy   | **Longest Palindrome from Letters**   | Leetcode 409 | Count pairs                  |        |
# | 🟢 Easy   | **Ransom Note**                       | Leetcode 383 | Char frequency check         |        |
# | 🟡 Medium | **Reorganize String 🎯**              | Leetcode 767 | Greedy + heap                |        |
# | 🟡 Medium | **Task Scheduler**                    | Leetcode 621 | Greedy arrange cooldowns     |        |
# | 🟡 Medium | **Valid Parenthesis String (Greedy)** | Leetcode 678 | Count flexibility range      |        |
# | 🟡 Medium | **Partition Labels**                  | Leetcode 763 | End index based partitioning |        |

# %% [markdown]
# # 🔹 7. Hybrid / Advanced Greedy (Still Internship-Level)
# | Level     | Problem                                        | Platform     | Key Idea                        | Status |
# | --------- | ---------------------------------------------- | ------------ | ------------------------------- | ------ |
# | 🟡 Medium | **Minimum Platforms 🎯**                       | GFG          | Sort arrivals/departures        |        |
# | 🟡 Medium | **Minimum Number of Arrows to Burst Balloons** | Leetcode 452 | Merge overlapping intervals     |        |
# | 🟡 Medium | **Jump Game II**                               | Leetcode 45  | Minimum steps with greedy range |        |
# | 🟡 Medium | **Task Scheduling with Deadlines**             | GFG          | Job priority                    |        |
# | 🟡 Medium | **Best Time to Buy and Sell Stock II**         | Leetcode 122 | Sum all upward profits          |        |
# | 🟡 Medium | **Partition Array into Disjoint Intervals**    | Leetcode 915 | Track max-left and min-right    |        |

# %% [markdown]
# dict

# %%
my_dict = {
    1: 2,
    23: 45,
    34: 13,
}
for key, value in my_dict.items():
    print(key, "and its value is:", value)
# ...existing code...
# Out:
# 1 and its value is: 2
# 23 and its value is: 45
# 34 and its value is: 13
