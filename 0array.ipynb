# %% [markdown]
# # 1. Basic Traversal & Prefix Techniques
# | Level     | Problem                       | Platform      | Key Idea              |
# | --------- | ----------------------------- | ------------- | --------------------- |
# | 🟢 Easy   | Running Sum of 1D Array 🎯    | Leetcode 1480 | Prefix sum basics     |
# | 🟢 Easy   | Pivot Index 🎯                | Leetcode 724  | Left sum vs right sum |
# | 🟢 Easy   | Majority Element 🎯           | Leetcode 169  | Boyer–Moore voting    |
# | 🟡 Medium | Subarray Sum Equals K 🎯      | Leetcode 560  | Prefix sum + hashmap  |
# | 🟡 Medium | Continuous Subarray Sum 🎯    | Leetcode 523  | Prefix mod trick      |
# | 🟡 Medium | Maximum Sum Circular Subarray | Leetcode 918  | Kadane + wrap case    |

# %% [markdown]
# # 2. Two Pointers (Classic)
# | Level     | Problem                                | Platform     | Key Idea                |
# | --------- | -------------------------------------- | ------------ | ----------------------- |
# | 🟢 Easy   | Two Sum II 🎯                          | Leetcode 167 | Two-pointer search      |
# | 🟢 Easy   | Remove Duplicates from Sorted Array 🎯 | Leetcode 26  | Slow/fast pointer       |
# | 🟢 Easy   | Sort Colors 🎯                         | Leetcode 75  | Dutch flag (3 pointers) |
# | 🟡 Medium | 3Sum 🎯                                | Leetcode 15  | Sorting + two pointers  |
# | 🟡 Medium | 4Sum 🎯                                | Leetcode 18  | Two-pointer extension   |
# | 🟡 Medium | Container With Most Water 🎯           | Leetcode 11  | Shrink rule             |
# | 🟡 Medium | Trapping Rain Water 🎯                 | Leetcode 42  | MaxLeft/Right pointers  |

# %% [markdown]
# # 3. Sliding Window (Fixed + Variable)
# | Level     | Problem                                           | Platform      | Key Idea          |
# | --------- | ------------------------------------------------- | ------------- | ----------------- |
# | 🟢 Easy   | Maximum Average Subarray                          | Leetcode 643  | Fixed window      |
# | 🟢 Easy   | Minimum Size Subarray Sum 🎯                      | Leetcode 209  | Variable window   |
# | 🟢 Easy   | Longest Subarray of 1s After Flips                | Leetcode 1004 | Window with flips |
# | 🟡 Medium | Longest Substring Without Repeating Characters 🎯 | Leetcode 3    | Window + freq     |
# | 🟡 Medium | Fruits Into Baskets 🎯                            | Leetcode 904  | At most 2 types   |
# | 🟡 Medium | Longest Repeating Character Replacement 🎯        | Leetcode 424  | Max freq window   |
# | 🟡 Medium | Sliding Window Maximum 🎯                         | Leetcode 239  | Deque monotonic   |

# %% [markdown]
# # 4. Hashmap / Frequency Patterns
# | Level     | Problem                         | Platform     | Key Idea                 |
# | --------- | ------------------------------- | ------------ | ------------------------ |
# | 🟢 Easy   | Two Sum 🎯                      | Leetcode 1   | Complement hashmap       |
# | 🟢 Easy   | First Unique Character          | Leetcode 387 | Frequency count          |
# | 🟢 Easy   | Intersection of Two Arrays II   | Leetcode 350 | Count occurences         |
# | 🟡 Medium | Group Anagrams 🎯               | Leetcode 49  | Sorted signature hashmap |
# | 🟡 Medium | Top K Frequent Elements 🎯      | Leetcode 347 | Heap or bucket           |
# | 🟡 Medium | Subarrays with K Distinct       | Leetcode 992 | Distinct count window    |
# | 🟡 Medium | Longest Consecutive Sequence 🎯 | Leetcode 128 | Set O(n)                 |

# %% [markdown]
# # 5. Sorting-Based Patterns
# | Level     | Problem                          | Platform     | Key Idea            |
# | --------- | -------------------------------- | ------------ | ------------------- |
# | 🟢 Easy   | Merge Sorted Array 🎯            | Leetcode 88  | Two-pointer merging |
# | 🟢 Easy   | Missing Number 🎯                | Leetcode 268 | XOR / sum / sort    |
# | 🟡 Medium | K Closest Points to Origin 🎯    | Leetcode 973 | Sort / heap         |
# | 🟡 Medium | Meeting Rooms II                 | Leetcode 253 | Sort start/end      |
# | 🟡 Medium | Minimum Arrows to Burst Balloons | Leetcode 452 | Interval sorting    |
# | 🟡 Medium | Insert Interval 🎯               | Leetcode 57  | Merge intervals     |

# %% [markdown]
# # 6. Binary Search on Arrays
# | Level     | Problem                                 | Platform     | Key Idea     |
# | --------- | --------------------------------------- | ------------ | ------------ |
# | 🟢 Easy   | Binary Search 🎯                        | Leetcode 704 | Standard     |
# | 🟢 Easy   | Search Insert Position 🎯               | Leetcode 35  | Lower bound  |
# | 🟢 Easy   | Guess Number Higher or Lower            | Leetcode 374 | BS           |
# | 🟡 Medium | Search in Rotated Sorted Array 🎯       | Leetcode 33  | Pivot logic  |
# | 🟡 Medium | Find Minimum in Rotated Sorted Array 🎯 | Leetcode 153 | Pivot BS     |
# | 🟡 Medium | Koko Eating Bananas 🎯                  | Leetcode 875 | BS on answer |
# | 🟡 Medium | Find Peak Element                       | Leetcode 162 | Mountain BS  |

# %% [markdown]
# # 7. Greedy on Arrays
# | Level     | Problem                | Platform      | Key Idea           |
# | --------- | ---------------------- | ------------- | ------------------ |
# | 🟢 Easy   | Assign Cookies         | Leetcode 455  | Greedy + sorting   |
# | 🟢 Easy   | Maximum Units on Truck | Leetcode 1710 | Sort by value      |
# | 🟡 Medium | Jump Game I 🎯         | Leetcode 55   | Furthest reach     |
# | 🟡 Medium | Jump Game II 🎯        | Leetcode 45   | Greedy levels      |
# | 🟡 Medium | Gas Station 🎯         | Leetcode 134  | Total fuel + pivot |
# | 🟡 Medium | Partition Labels 🎯    | Leetcode 763  | Greedy split       |

# %% [markdown]
# # 8. Matrix / 2D Arrays
# | Level     | Problem              | Platform     | Key Idea            |
# | --------- | -------------------- | ------------ | ------------------- |
# | 🟢 Easy   | Reshape the Matrix   | Leetcode 566 | Mapping indices     |
# | 🟢 Easy   | Transpose Matrix     | Leetcode 867 | Swap rows/cols      |
# | 🟢 Easy   | Spiral Matrix I 🎯   | Leetcode 54  | Layer traversal     |
# | 🟡 Medium | Spiral Matrix II     | Leetcode 59  | Fill spiral         |
# | 🟡 Medium | Rotate Image 🎯      | Leetcode 48  | Transpose + reverse |
# | 🟡 Medium | Set Matrix Zeroes 🎯 | Leetcode 73  | In-place markers    |
# | 🟡 Medium | Game of Life         | Leetcode 289 | State marking       |

# %% [markdown]
# # 9. Prefix, Suffix, Kadane & Variants
# | Level     | Problem                               | Platform     | Key Idea        |
# | --------- | ------------------------------------- | ------------ | --------------- |
# | 🟢 Easy   | Maximum Subarray (Kadane) 🎯          | Leetcode 53  | Max subarray DP |
# | 🟢 Easy   | Find Pivot Index                      | Leetcode 724 | Prefix sums     |
# | 🟡 Medium | Maximum Product Subarray 🎯           | Leetcode 152 | Min/max DP      |
# | 🟡 Medium | Shortest Unsorted Continuous Subarray | Leetcode 581 | Boundary expand |
# | 🟡 Medium | Subarray Product < K                  | Leetcode 713 | Sliding window  |
# | 🟡 Medium | Range Sum Query (Immutable)           | Leetcode 303 | Prefix query    |

# %% [markdown]
# # 10. Heap / Priority Queue on Arrays
# | Level     | Problem                         | Platform      | Key Idea           |
# | --------- | ------------------------------- | ------------- | ------------------ |
# | 🟢 Easy   | Last Stone Weight               | Leetcode 1046 | Max-heap           |
# | 🟢 Easy   | Kth Largest Element (Stream)    | Leetcode 703  | Min-heap           |
# | 🟡 Medium | Kth Largest Element in Array 🎯 | Leetcode 215  | Heap / quickselect |
# | 🟡 Medium | Merge K Sorted Lists            | Leetcode 23   | Heap of heads      |
# | 🟡 Medium | Reorganize String               | Leetcode 767  | Max-heap freq      |
# | 🟡 Medium | Task Scheduler                  | Leetcode 621  | Greedy + heap      |

# %% [markdown]
# # 11. Advanced Array Tricks (Cyclic Sort, XOR, In-place swaps)
# | Level     | Problem                      | Platform     | Key Idea         |
# | --------- | ---------------------------- | ------------ | ---------------- |
# | 🟢 Easy   | Missing Number 🎯            | Leetcode 268 | XOR / cyclic     |
# | 🟢 Easy   | Find All Numbers Disappeared | Leetcode 448 | Cyclic marking   |
# | 🟢 Easy   | Find the Duplicate Number 🎯 | Leetcode 287 | Floyd’s cycle    |
# | 🟡 Medium | First Missing Positive 🎯    | Leetcode 41  | Cyclic bucket    |
# | 🟡 Medium | Set Mismatch                 | Leetcode 645 | Cyclic fix       |
# | 🟡 Medium | Find All Duplicates          | Leetcode 442 | In-place marking |

# %% [markdown]
# # 12. Intervals (Array + Sorting)
# | Level     | Problem                                      | Platform     | Key Idea                             |
# | --------- | -------------------------------------------- | ------------ | ------------------------------------ |
# | 🟢 Easy   | Merge Intervals (Simplified Versions on GFG) | GFG          | Sort + merge ranges                  |
# | 🟢 Easy   | Meeting Rooms I 🎯                           | Leetcode 252 | Check overlap using sorted intervals |
# | 🟢 Easy   | Can Attend All Meetings                      | Leetcode 252 | Sort by start time                   |
# | 🟡 Medium | Merge Intervals 🎯                           | Leetcode 56  | Merge overlapping intervals          |
# | 🟡 Medium | Insert Interval 🎯                           | Leetcode 57  | Insert + merge                       |
# | 🟡 Medium | Meeting Rooms II                             | Leetcode 253 | Min-heaps / tracking rooms           |
# | 🟡 Medium | Non-overlapping Intervals 🎯                 | Leetcode 435 | Greedy — remove minimum              |
# | 🟡 Medium | Minimum Arrows to Burst Balloons             | Leetcode 452 | Greedy — interval end                |
# | 🟡 Medium | Interval List Intersections 🎯               | Leetcode 986 | Two-pointer interval traversal       |
# | 🟡 Medium | Employee Free Time                           | Leetcode 759 | Merge + complement intervals         |
